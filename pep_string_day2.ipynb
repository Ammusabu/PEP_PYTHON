# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammusabu/PEP_PYTHON/blob/main/pep_string_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# String
s = "Python Programming"

print(s)                 # Prints the original string
print(len(s))            # Prints length of the string
print(s[0])              # Prints first character
print(s[-1])             # Prints last character
print(s[7:18])           # Prints substring using slicing

print(s.lower())         # Converts string to lowercase
print(s.upper())         # Converts string to uppercase

print(s)                 # Prints original string again
print(s.strip())         # Removes leading and trailing spaces

print(s.replace("Python", "Java"))  # Replaces a word in the string
print(s.split(" "))      # Splits string into a list of words

print(s)                 # Prints original string

print(s.find("P"))       # Finds position of character 'P'

word = s.split()         # Splits string into words
print(word)

b = "abc"
print(b.isdigit())       # Checks if string contains only digits
print(b.isalpha())       # Checks if string contains only alphabets

print(s.count("P"))      # Counts number of occurrences of 'P'
print(s.startswith("P")) # Checks if string starts with 'P'
print(s.endswith("g"))   # Checks if string ends with 'g'
print(s.capitalize())    #
#reverse a string
print(s[::-1])
# Out:
# Python Programming
# 18
# P
# g
# Programming
# python programming
# PYTHON PROGRAMMING
# Python Programming
# Python Programming
# Java Programming
# ['Python', 'Programming']
# Python Programming
# 0
# ['Python', 'Programming']
# False
# True
# 2
# True
# True
# Python programming
# gnimmargorP nohtyP

# %%
a = "ammusabu"
print(a.capitalize())
print(a.lower())
print(a.upper())
print(a.find("a"))
print(len(a))
print(a.count("u"))
print(a[::-1])
print(a.isalpha())
# Out:
# Ammusabu
# ammusabu
# AMMUSABU
# 0
# 8
# 2
# ubasumma
# True
# 4

# %%
#vowels count
count =0
for i in a:
    if i in "aeiouAEIOU":
        count+=1
print(count)
# Out:
# 4

# %%
#palindrome check
s = "malayalam"
if s == s[::-1]:
    print("palindrome")
else:
    print("not palindrome")
# Out:
# palindrome

# %%
#make 2 pointer approach
s = "madam"

left = 0
right = len(s) - 1

while left < right:
    if s[left] != s[right]:
        print("Not a Palindrome")
        break
    left += 1
    right -= 1
else:
    print("Palindrome")
# Out:
# Palindrome

# %%
#count characters of a string
m = "Apple"
for ch in m:
    print(ch,":", m.count(ch))
# Out:
# A : 1
# p : 2
# p : 2
# l : 1
# e : 1

# %%
#replace vowel with a star
l= "Lovely Professional University"
for ch in l:
    if ch in "aeiouAEIOU":
        l = l.replace(ch, "*")
    else:
        l = l.replace(ch, ch)
print(l)
# Out:
# L*v*ly Pr*f*ss**n*l *n*v*rs*ty

# %%
#same in another way
l = "Lovely Professional University"
result=""
for ch in l:
    if ch in "aeiouAEIOU":
        result += "*"
    else:
        result += ch
print(result)
#
# Out:
# L*v*ly Pr*f*ss**n*l *n*v*rs*ty

# %% [markdown]
# **File handling**

# %%
#write file
#file = open("sample.txt", "mode->r,w,a")
file = open("Students.txt", "w")
file.write("Name: Rahul \n")
file.write("Age: 20 \n")
file.write("Address: Delhi \n")
file.close()

# %%
#reading file
file = open("Students.txt", "r")
data = file.read()
print(data)
file.close()
# Out:
# Name: Rahul
# Age: 20
# Address: Delhi

# %%
#another way to read
with open("Students.txt", "r") as file:
    data = file.read()
    print(data)
# Out:
# Name: Rahul
# Age: 20
# Address: Delhi

# %%
#adding data
file = open("Students.txt", "a")
file.write("marks: 90\n")
file.close()

# %%
file = open("Students.txt", "r")
data = file.readline()
print(data)
# Out:
# Name: Rahul

# %%
file = open("Students.txt", "r")
data2 =file.readlines()
print(data2)
file.close()
# Out:
# ['Name: Rahul \n', 'Age: 20 \n', 'Address: Delhi \n', 'marks: 90\n', 'marks: 90\n']

# %%
file = open("data.txt","w")
file.write("Name: Ammu\n")
file.write("City: Alleppy\n")
file.write("Age: 20\n")
file.close()

# %%
file = open("data.txt","r")
data = file.read()
print(data)
file.close()
# Out:
# Name: Ammu
# City: Alleppy
# Age: 20

# %%
file = open("data.txt","a")
file.write("Marks: 90\n")
file.close()

# %%
file = open("data.txt","r")
data = file.readline()
print(data)
file.close()
# Out:
# Name: Ammu

# %%
file = open("data.txt","r")
data = file.readlines()
print(data)
file.close()
# Out:
# ['Name: Ammu\n', 'City: Alleppy\n', 'Age: 20\n', 'Marks: 90\n']

# %%
#for number of lines
file = open("data.txt","r")
data = file.readlines()
print(len(data))
file.close()
# Out:
# 4

# %%
file = open("string.txt",'w')
content = "My name is Ammu Sabu\n"
file.write(content)
file.write(content.upper())
file.close()

# %%
file = open("string.txt",'r')
data = file.read()
print(data)
file.close()
# Out:
# My name is Ammu Sabu
# MY NAME IS AMMU SABU

# %%
file = open("string.txt",'a')
file.write("\nI am from Alleppy")
file.close()

# %%
#number of characters
file = open("string.txt",'r')
data = file.read()
print(len(data))
file.close()
# Out:
# 60

# %%
#words count
file = open("string.txt",'r')
data = file.read()
words = data.split()
print(len(words))
print(data.count("is"))
file.close()
# Out:
# 14
# 1

# %%
#letter count
file = open("string.txt",'r')
data = file.read()
count = data.lower().count("a")
print("Word count:", count)
file.close()
# Out:
# Word count: 8

# %%
#reverse
file =open("string.txt",'r')
data = file.read()
print(data[::-1])
file.close()
# Out:
# yppellA morf ma I
#
# UBAS UMMA SI EMAN YM
# ubaS ummA si eman yM

# %%
#replace
file = open("string.txt",'r')
data = file.read()
print(data.replace("Ammu","priya"))
file.close()
# Out:
# My name is priya Sabu
# MY NAME IS AMMU SABU
#
# I am from Alleppy

# %%
file = open("movies.txt:", 'w')
contents = "prestige\n avatar\ninception\n"
file.write(contents)
file.close()

# %%
file = open("movies.txt:",'r')
data = file.read()
print(data[:10])
file.close()
# Out:
# prestige

# %%
file = open("movies.txt:",'r')
data = file.read()
print(data.strip())
file.close()
# Out:
# prestige
#  avatar
# inception

# %%
file = open("movies.txt:",'r')
data = file.read()
print(data.replace(" ",""))
file.close()
# Out:
# prestige
# avatar
# inception

# %%
file = open("movies.txt:","r")
data = file.read()
words = data.split()
for w in words:
    print(w[::-1])
file.close()
# Out:
# egitserp
# ratava
# noitpecni

# %% [markdown]
# **Exception Handling**

# %%
try:
  #riskycode
except:
  #error handling code

# %%
try:
  a = int(input("Enter a number: "))
  b = int(input("Enter a number: "))
  c = a/b
  print(c)
except:
  print("Invalid input!!!!!!!!")
# Out:
# Enter a number: 8
# Enter a number: 0
# Invalid input!!!!!!!!

# %% [markdown]
# Exception handling in file

# %%
try:
  file = open("movies.txt","r")
  print(file.read())
  file.close()
except FileNotFoundError:
  print("File not found")
else:
  print("File opened successfully")
finally:
  print("program ends")
# Out:
# File not found
# program ends
