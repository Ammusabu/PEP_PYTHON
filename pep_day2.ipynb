# %% [markdown]
# <a href="https://colab.research.google.com/github/Ammusabu/PEP_PYTHON/blob/main/pep_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dictionary
student = {"name": "rahul",
           "age": 2,
           "city": "Delhi",
           "course": "Python"
           }
print(student)
print(student["name"])
print(student["age"])
print(student["city"])
print(student["course"])
print(student.get("name"))
print(student.get("age"))
print(student.get("city"))
print(student.get("course"))
# Out:
# {'name': 'rahul', 'age': 2, 'city': 'Delhi', 'course': 'Python'}
# rahul
# 2
# Delhi
# Python
# rahul
# 2
# Delhi
# Python

# %%
print(student.keys())#for keys
print(student.values())#for values alone
print(student.items())#for printing all values
student.update({"age":46,"course":"django"})#for updating the value
print(student)
# Out:
# dict_keys(['name', 'age', 'city', 'course'])
# dict_values(['rahul', 46, 'Delhi', 'django'])
# dict_items([('name', 'rahul'), ('age', 46), ('city', 'Delhi'), ('course', 'django')])
# {'name': 'rahul', 'age': 46, 'city': 'Delhi', 'course': 'django'}

# %%
dict1 = {"a": 2,
         "b": 3}
dict2= {"c": 4,
        "d": 5}
dict2 = dict1.copy()#for copying dict
print(student)
print(len(student))#for length
dict1.update(dict2)#for updating the dict
print(dict1)
# Out:
# {'name': 'rahul', 'age': 46, 'city': 'Delhi', 'course': 'django'}
# 4
# {'a': 2, 'b': 3}

# %%
dict3 = {"brand": "samsung",
         "model":"s23",
         "price":50000,
         "stock":10
         }
print(dict3)
print(dict3.keys())
print(dict3.values())
print(dict3.items())
print(dict3.get("brand"))
print(dict3.get("model"))
print(dict3.get("price"))
print(dict3.get("stock"))
dict3.update({"price":60000,"stock":20})
print(dict3)
print(len(dict3))
dict3.pop("stock")
print(dict3)
dict3.popitem()
print(dict3)
# Out:
# {'brand': 'samsung', 'model': 's23', 'price': 50000, 'stock': 10}
# dict_keys(['brand', 'model', 'price', 'stock'])
# dict_values(['samsung', 's23', 50000, 10])
# dict_items([('brand', 'samsung'), ('model', 's23'), ('price', 50000), ('stock', 10)])
# samsung
# s23
# 50000
# 10
# {'brand': 'samsung', 'model': 's23', 'price': 60000, 'stock': 20}
# 4
# {'brand': 'samsung', 'model': 's23', 'price': 60000}
# {'brand': 'samsung', 'model': 's23'}
# {}

# %%
contact = {}

while True:
    print("\n---- Contact Book ----")
    print("1. Add contact")
    print("2. View contacts")
    print("3. Search contact")
    print("4. Delete contact")
    print("5. Exit")

    choice = int(input("Enter your choice: "))

    # 1. Add contact
    if choice == 1:
        name = input("Enter name: ")
        phone = input("Enter phone: ")
        contact[name] = phone
        print("Contact added successfully")

    # 2. View contacts
    elif choice == 2:
        if contact:
            print("\nSaved Contacts:")
            for name, phone in contact.items():
                print(name, ":", phone)
        else:
            print("No contacts found")

    # 3. Search contact
    elif choice == 3:
        name = input("Enter name to search: ")
        if name in contact:
            print(name, ":", contact[name])
        else:
            print("Contact not found")

    # 4. Delete contact
    elif choice == 4:
        name = input("Enter name to delete: ")
        if name in contact:
            del contact[name]
            print("Contact deleted successfully")
        else:
            print("Contact not found")

    # 5. Exit
    elif choice == 5:
        print("Exiting Contact Book")
        break

    else:
        print("Invalid choice! Please try again")
# Out:
# ---- Contact Book ----
# 1. Add contact
# 2. View contacts
# 3. Search contact
# 4. Delete contact
# 5. Exit
# Contact added successfully
#
# ---- Contact Book ----
# 1. Add contact
# 2. View contacts
# 3. Search contact
# 4. Delete contact
# 5. Exit
#
# Saved Contacts:
# Ammu S : 9074207070
#
# ---- Contact Book ----
# 1. Add contact
# 2. View contacts
# 3. Search contact
# 4. Delete contact
# 5. Exit
# Contact not found
#
# ---- Contact Book ----
# 1. Add contact
# 2. View contacts
# 3. Search contact
# 4. Delete contact
# 5. Exit
# Contact added successfully
#
# ---- Contact Book ----
# 1. Add contact
# 2. View contacts
# 3. Search contact
# 4. Delete contact
# 5. Exit
# Contact added successfully
#
# ---- Contact Book ----
# 1. Add contact
# 2. View contacts
# 3. Search contact
# 4. Delete contact
# 5. Exit
# Contact added successfully
#
# ---- Contact Book ----
# 1. Add contact
# 2. View contacts
# 3. Search contact
# 4. Delete contact
# 5. Exit
# Contact added successfully
#
# ...

# %%
Student = {}

while True:
    print("\n---- Student Database ----")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Delete Student")
    print("5. Exit")

    choice = int(input("Enter your choice: "))

    # 1. Add Student
    if choice == 1:
        name = input("Enter name: ")
        rollnumber = input("Enter roll number: ")
        course = input("Enter course: ")
        Student[name] = (rollnumber, course)
        print("Student added successfully")

    # 2. View Students
    elif choice == 2:
        if Student:
            print("\nSaved Students:")
            for name, details in Student.items():
                print("Name:", name)
                print("Roll No:", details[0])
                print("Course:", details[1])
                print("------------------")
        else:
            print("No students found")

    # 3. Search Student by Roll Number
    elif choice == 3:
        search_roll = input("Enter roll number to search: ")
        found = False
        for name, details in Student.items():
            if details[0] == search_roll:
                print("Student Found")
                print("Name:", name)
                print("Roll No:", details[0])
                print("Course:", details[1])
                found = True
                break
        if not found:
            print("Student not found")

    # 4. Delete Student
    elif choice == 4:
        name = input("Enter name to delete: ")
        if name in Student:
            del Student[name]
            print("Student deleted successfully")
        else:
            print("Student not found")

    # 5. Exit
    elif choice == 5:
        print("Exiting Student Database")
        break

    else:
        print("Invalid choice! Please try again")

# %%
#String
s = "Python Programming"
print(s)
print(len(s))
print(s[0])
print(s[-1])
print(s[7:18])
print((s.lower))
print(s.upper())
print(s)
print(s.strip())
print(s.replace("Python","Java"))
print(s.split(" "))
print(s)
